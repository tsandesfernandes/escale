# %% [markdown]
# <a href="https://colab.research.google.com/github/tsandesfernandes/escale/blob/master/escale_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!apt-get install openjdk-8-jdk-headless -qq > /dev/null
#!wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
#!tar xf spark-2.4.4-bin-hadoop2.7.tgz
#!pip install -q findspark

import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = '/content/gdrive/My Drive/escale/'
os.chdir(root_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from pyspark.sql import SparkSession
from pyspark.sql import *
from pyspark.sql import functions as F
from pyspark.sql import types as T

from pyspark.sql.window import Window

# %%
spark = SparkSession.builder.master('local[*]').getOrCreate()
sc = spark.sparkContext

# %%
dir = os.listdir(".")

# %%
df = spark.read.json('/content/gdrive/My Drive/escale/part-00000.json.gz') #teste

# %%
df.printSchema()
# Out:
# root
#  |-- anonymous_id: string (nullable = true)
#  |-- browser_family: string (nullable = true)
#  |-- device_family: string (nullable = true)
#  |-- device_sent_timestamp: long (nullable = true)
#  |-- event: string (nullable = true)
#  |-- n: long (nullable = true)
#  |-- os_family: string (nullable = true)
#  |-- platform: string (nullable = true)
#  |-- version: string (nullable = true)

# %%
#df.show(2)

# %%
schema = T.StructType([
                    T.StructField('anonymous_id', T.StringType(), False),
                    T.StructField('browser_family', T.StringType(), False),
                    T.StructField('device_family', T.StringType(), False),
                    T.StructField('device_sent_timestamp', T.LongType(), False),
                    T.StructField('event', T.StringType(), True),
                    T.StructField('n', T.LongType(), True),
                    T.StructField('os_family', T.StringType(), False),
                    T.StructField('plataform', T.StringType(), True),
                    T.StructField('version', T.StringType(), True),
                    T.StructField('filename', T.StringType(), True)   
])
df = spark.createDataFrame(sc.emptyRDD(), schema)

# %%
for file in dir:
  if 'part' in file:
    path = "{}/{}".format(os.getcwd(), file)
    json_df = spark.read.json(path)
    json_df = json_df.withColumn('filename', F.lit(path.split('/')[-1]))
    df = df.union(json_df)

# %%
#df = df.limit(40) #remover no final

# %%
df = df.withColumn('device_date', (df["device_sent_timestamp"]/1000).cast("timestamp"))

# %%
#df.show(5)

# %%
#anonymous_id nao serve como sessao
#df.groupby('anonymous_id').count().alias('count').sort('count', ascending=False).show(20)

# %%
session_cols = [F.col('browser_family'), F.col('device_family'), F.col('os_family')]

# %%
df = df.withColumn('session_id', F.lit(F.concat(*session_cols)))

# %%
df = df.sort(F.col('session_id'), F.col('device_sent_timestamp'), ascending=True)

# %%
window = Window.partitionBy('session_id').orderBy('device_sent_timestamp')

# %%
df = df.withColumn("minutes_diff", F.coalesce( ( F.col('device_sent_timestamp') - F.lag(F.col('device_sent_timestamp')).over(window) ) / 60000,F.lit(0)) )

# %%
#df.show(5)

# %%
df = df.withColumn("is_new_session", F.when( (F.col('minutes_diff') > 30) | (F.col('minutes_diff') == 0.0) , F.lit(1) ).otherwise(F.lit(0)))

# %%
#df.show(20)

# %%
df.printSchema()
# Out:
# root
#  |-- anonymous_id: string (nullable = true)
#  |-- browser_family: string (nullable = true)
#  |-- device_family: string (nullable = true)
#  |-- device_sent_timestamp: long (nullable = true)
#  |-- event: string (nullable = true)
#  |-- n: long (nullable = true)
#  |-- os_family: string (nullable = true)
#  |-- plataform: string (nullable = true)
#  |-- version: string (nullable = true)
#  |-- filename: string (nullable = true)
#  |-- device_date: timestamp (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- minutes_diff: double (nullable = false)
#  |-- is_new_session: integer (nullable = false)

# %%
#resultado parte 1
resultado_1_df = df.groupby('filename').agg(F.sum(F.col('is_new_session')).alias('sessoes_unicas'))

# %%
resultado_1_dict = {}
for row in resultado_1_df.collect():
  resultado_1_dict[row['filename']] = row['sessoes_unicas']

# %%
resultado_1_dict
# Out:
# {'part-00000.json.gz': 8267,
#  'part-00001.json.gz': 13953,
#  'part-00002.json.gz': 19552,
#  'part-00003.json.gz': 25187,
#  'part-00004.json.gz': 30932,
#  'part-00005.json.gz': 36500,
#  'part-00006.json.gz': 41822,
#  'part-00007.json.gz': 47512,
#  'part-00008.json.gz': 53304,
#  'part-00009.json.gz': 58894}

# %%
#resultado parte 2
def unique_by_column(column):
  return df.groupby(column).agg(F.sum(F.col('is_new_session')).alias('sessoes_unicas'))

# %%
columns = ['browser_family', 'os_family', 'device_family']
resultado_2_dict = {}
for column in columns:
  df_2 = unique_by_column(F.col(column))
  in_dict = {}
  for row in df_2.collect():
    in_dict[row[column]] = row['sessoes_unicas']
  resultado_2_dict[column] = in_dict

# %%
resultado_2_dict
# Out:
# {'browser_family': {'AdsBot-Google': 376,
#   'Amazon Silk': 19,
#   'Android': 7,
#   'AppleMail': 24,
#   'Applebot': 1,
#   'BingPreview': 9,
#   'Chrome': 16252,
#   'Chrome Mobile': 210139,
#   'Chrome Mobile iOS': 205,
#   'Chromium': 77,
#   'Edge': 149,
#   'Edge Mobile': 53,
#   'Facebook': 23350,
#   'Firefox': 762,
#   'Firefox Mobile': 166,
#   'Firefox iOS': 88,
#   'GooglePlusBot': 1,
#   'Googlebot': 71965,
#   'IE': 4,
#   'IE Mobile': 6,
#   'Investment Crawler': 3,
#   'Maxthon': 8,
#   'Mobile Safari': 4107,
#   'Mobile Safari UIWebView': 2969,
#   'Opera': 372,
#   'Opera Mini': 2,
#   'Opera Mobile': 370,
#   'Other': 3821,
#   'Pale Moon (Firefox Variant)': 2,
#   'PetalBot': 9,
#   'Pinterest': 3,
#   'Puffin': 29,
#   'SMTBot': 7,
#   'Safari': 120,
#   'SeaMonkey': 2,
#   'UC Browser': 400,
#   'Vivaldi': 21,
#   'Yahoo! Slurp': 1,
#   'Yandex Browser': 24},
#  'device_family': {'XiaoMi Redmi 7': 277,
#   'iPhone11,2': 162,
#   'MS50L_4G': 6,
#   'XiaoMi Redmi Go': 145,
#   'KYY23': 1,
#   'Samsung SM-G970N': 2,
#   'iPad6,12': 2,
#   'Pixel 2 XL': 4,
#   'Samsung SM-G770F': 32,
#   'Samsung SM-A730F': 301,
#   'KING 7': 1,
#   'ML-TI-MS80': 11,
#   'MZ-MX4': 4,
#   'XT1225': 28,
#   'LG-D337': 156,
#   'Samsung SM-J260M': 225,
#   'Lenovo K53b36': 210,
#   '5159J': 80,
#   'LG-V480': 3,
#   'Samsung SM-T865': 1,
#   'M7_3G_PLUS': 4,
#   'ZE553KL': 80,
#   'C6': 3,
#   'XT621': 4,
#   'BLU NEO X MINI': 1,
#   'S60': 9,
#   'XiaoMi Redmi S2': 184,
#   'Grand X': 4,
#   'Samsung SM-T705M': 2,
#   'Samsung SM-G935T': 3,
#   'XT1585': 1,
#   'Samsung SM-T285YD': 1,
#   'MZ-M5 Note': 3,
#   'Samsung SM-T330': 7,
#   'Nokia 2': 26,
#   'Samsung GT-S7583T': 2,
#   'C6943': 11,
#   'iPhone6,2': 135,
#   'ZTE Blade L5': 1,
#   'LG-H502': 51,
#   'Samsung SM-N960F': 43,
#   'Moto X4': 2,
#   'XiaoMi Redmi 6': 271,
#   'LG-H860': 8,
#   'LG-H342': 45,
#   'Samsung SM-A507FN': 1,
#   'MS55M': 6,
#   'HTC 10 evo': 1,
#   'Samsung SM-N976U': 3,
#   'MX9-4K': 1,
#   'Sky': 6,
#   'Spider': 72354,
#   'Samsung SM-G920V': 11,
#   'Z Play': 3,
#   'Samsung SM-T561M': 9,
#   'MN4A2ZP/A': 1,
#   'Samsung SM-A202F': 12,
#   'NX591J': 16,
#   'U2': 4,
#   'Lenovo K10a40': 188,
#   'Samsung SM-A700FD': 36,
#   'Samsung SM-T110': 6,
#   'Meizu M6s': 2,
#   'Samsung SM-G950F': 278,
#   'TV BOX': 1,
#   'Samsung SM-G960U': 24,
#   'Samsung SM-G935U': 3,
#   'Samsung SM-G530T': 2,
#   'LG-H831': 1,
#   'Samsung SM-G316M': 3,
#   'LG-H221': 4,
#   'Archos Core 50 4G': 1,
#   '5085N': 18,
#   'MotoE2(4G-LTE)': 54,
#   'iPad': 194,
#   'Samsung SM-G9750': 1,
#   'Moto G (5S) Plus': 210,
#   'LG-H931': 1,
#   'G_Pro': 18,
#   'Lenovo TB2-X30F': 1,
#   'G3311': 4,
#   'Moto G (4)': 312,
#   'D5803': 2,
#   'X21 Plus': 1,
#   'Samsung SM-J701MT': 211,
#   'Positivo Twist 4G': 44,
#   'M10A': 2,
#   'Samsung SM-A750G': 347,
#   'Lumia 950': 1,
#   'Samsung SM-G973U1': 8,
#   'D5833': 2,
#   '5016J': 14,
#   'Samsung SM-N950U': 18,
#   'iPad3,5': 8,
#   'Samsung SM-G3502T': 4,
#   'XiaoMi Redmi 8': 248,
#   'Samsung SM-A530F': 335,
#   'Samsung SM-G850F': 1,
#   'Samsung SM-T311': 2,
#   '91S': 1,
#   'Grand XL': 4,
#   'Samsung SM-A520F': 307,
#   'HS007C': 1,
#   'Vivo 5 Mini': 3,
#   'Samsung SM-N935F': 1,
#   'Positivo Slim': 9,
#   'VFD 620': 1,
#   'Asus X00TDB': 315,
#   'Samsung SM-A750GN': 7,
#   'XT1563': 3,
#   'XiaoMi MI 9': 306,
#   'Samsung SM-J250F': 2,
#   'LEX651': 1,
#   'Samsung SM-G9730': 3,
#   'BBC100-1': 2,
#   'Samsung SM-J415FN': 9,
#   'You L': 4,
#   'Samsung SM-J727U': 4,
#   'Asus I001DD': 5,
#   'Moto E': 2,
#   'iPhone10,4': 82,
#   'LG-D385': 21,
#   'S10': 1,
#   'moto g6 plus': 1,
#   'M7sLite': 2,
#   'F': 74,
#   'iPhone9,2': 146,
#   'XiaoMi Redmi Note 5': 251,
#   'Lenovo A2016b30': 193,
#   'X50A': 1,
#   'PHONEMAX_Saturn': 3,
#   'DUB-LX3': 3,
#   'iPad3,3': 1,
#   'SGP311': 2,
#   'Archos 60 Platinum': 1,
#   'Samsung SM-J510FN': 5,
#   'INE-LX1': 2,
#   'STV100-3': 1,
#   'F5122': 17,
#   'iPhone7,2': 86,
#   'MotoG3-TE': 47,
#   'Samsung SM-G600FY': 258,
#   'MIX 2': 6,
#   'E6653': 2,
#   'Nokia 7 plus': 3,
#   'LG-H326': 37,
#   'Kingbox': 1,
#   'moto g(6) plus': 138,
#   'Samsung SM-N960N': 6,
#   'Samsung SM-G900F': 17,
#   'Platinum_5.0M': 1,
#   'Samsung SM-P585M': 26,
#   'Positivo Twist M': 33,
#   'Samsung SM-A305FN': 1,
#   'iPhone10,6': 101,
#   'ML-WI-M9-3G': 3,
#   'Samsung SM-P555M': 8,
#   'Samsung GT-S5303B': 1,
#   'Samsung SM-G532M': 283,
#   'Asus X00LDA': 88,
#   'Le X520': 2,
#   'LG-H815': 36,
#   'Samsung SM-J701F': 11,
#   'Samsung SM-N910A': 3,
#   'Samsung SM-J727T': 1,
#   'INE-LX2': 1,
#   'XiaoMi MI 8': 186,
#   'Lenovo A7600-F': 1,
#   'XT1025': 15,
#   'D6643': 2,
#   'Samsung SM-G900H': 3,
#   'XT1609': 1,
#   'MS80X': 15,
#   'Samsung SM-T295': 44,
#   'Armor_3': 4,
#   'Samsung SM-G935F': 322,
#   'Samsung GT-I9505G': 1,
#   'Nexus 5': 114,
#   'T96 Mars': 2,
#   'HUAWEI LUA-U23': 4,
#   'Asus Z00XS': 6,
#   'Samsung GT-I8200L': 3,
#   'MYA-L11': 1,
#   'Samsung SM-P200': 1,
#   'Samsung GT-P5210': 3,
#   'Twist Tab': 1,
#   'Samsung SM-A920F': 310,
#   'Samsung GT-I8262B': 4,
#   'Samsung SM-N960U': 20,
#   'E6553': 2,
#   'Samsung GT-I8190L': 7,
#   'KFAUWI': 1,
#   'iPad7,3': 1,
#   'M5c': 4,
#   'Advance L4': 3,
#   'BV8000Pro': 2,
#   'NV6': 2,
#   'Nokia 2.3': 2,
#   'LM-X210': 284,
#   'Samsung SM-G920I': 206,
#   'XiaoMi Redmi Note 6 Pro': 315,
#   'TVBOX': 2,
#   'Samsung SM-T555': 2,
#   'Samsung GT-S7273T': 18,
#   'S8': 9,
#   'Samsung SM-J320F': 3,
#   'M5s': 1,
#   'Huawei Browser': 18,
#   'LG-K500n': 4,
#   '4009E': 2,
#   'Samsung SM-T585': 4,
#   'GO3E': 28,
#   'LEX720': 1,
#   'Samsung SM-G530H': 59,
#   '1001-G Go': 14,
#   'Armor_6': 5,
#   'Samsung GT-S7560M': 2,
#   'MS50M': 3,
#   'Samsung SM-P205': 4,
#   'Power 3S': 2,
#   'Samsung SM-G316ML': 10,
#   'Samsung SM-A115M': 3,
#   'S60Lite': 7,
#   'Samsung SM-G928A': 3,
#   'Samsung GT-I9082': 1,
#   'S30': 1,
#   'LG-D325': 35,
#   'Z971': 3,
#   '5017E': 4,
#   'LG-K220': 248,
#   'Samsung SM-G930T': 3,
#   'XiaoMi Redmi 5': 42,
#   'Samsung SM-J510MN': 328,
#   'Samsung SM-J100M': 6,
#   'Samsung SM-J105M': 119,
#   'F_Pro': 3,
#   'SUPER': 3,
#   'XiaoMi Redmi K20': 5,
#   'Twist 2 Go': 4,
#   'XiaoMi Redmi Note 5A': 7,
#   'Samsung SM-G6100': 2,
#   'Samsung SM-G130BU': 2,
#   'Le X620': 1,
#   'XiaoMi Redmi Note 4': 163,
#   'Samsung SM-G970X': 2,
#   'Asus X018D': 148,
#   'LG-H870DS': 8,
#   'Samsung SM-G900M': 147,
#   'Samsung SM-G890A': 3,
#   'Samsung GT-P5200': 6,
#   'LG-K520': 8,
#   'LM-X420': 94,
#   'Samsung SM-M205M': 318,
#   'Samsung SM-T530': 2,
#   'Samsung SM-N975F': 323,
#   'X206': 1,
#   'Samsung SM-G955U': 30,
#   'HDT-7427G': 7,
#   'Samsung SM-A305GN': 1,
#   'Nokia 3.1 Plus': 3,
#   'LG-H930': 2,
#   'Samsung SM-A305G': 21,
#   'MS50L': 132,
#   'K3': 1,
#   'LG-X210': 22,
#   'Positivo Twist S': 47,
#   'iPhone12,8': 35,
#   'DUA-L22': 5,
#   'LG-M320G': 1,
#   'Samsung SM-G9600': 263,
#   'iPhone': 4315,
#   'D2212': 8,
#   'Samsung SM-J320FN': 9,
#   'XT1799-2': 1,
#   'Samsung SM-A750FN': 6,
#   'PTB7PAP_PTB7PAB_PTB7PAR': 4,
#   'BLL-L23': 4,
#   'Samsung SM-A305GT': 136,
#   'Samsung SM-J330G': 1,
#   'Asus Z00YD': 13,
#   'LG-D157f': 2,
#   'Moto G 2014': 4,
#   'Samsung SM-J326AZ': 1,
#   'LG-TP260': 2,
#   'Samsung SM-N915T': 11,
#   'Samsung SM-G900MD': 39,
#   'E': 35,
#   'iPhone5,1': 56,
#   'HTC One M9': 1,
#   'XiaoMi MI A3': 3,
#   'LG-H870S': 1,
#   'MONDIAL': 1,
#   'JSN-L21': 1,
#   '8050E': 125,
#   '5060D': 1,
#   'S430 Positivo Twist Mini': 4,
#   'Asus X00QD': 312,
#   'Lenovo K33a42': 5,
#   'HT-705XS': 2,
#   'Samsung SM-J700T1': 5,
#   'Samsung SM-J260MU': 30,
#   'Samsung SM-J106M': 1,
#   'GIONEE S11 lite': 2,
#   'Samsung SM-A600FN': 3,
#   'LG-D410': 42,
#   'iPad8,3': 3,
#   'LG-E435f': 2,
#   'iPhone11,6': 114,
#   'Samsung SM-J530F': 2,
#   'Nexus 5X': 7,
#   'Meizu M6': 1,
#   'LG-E977': 4,
#   'iPhone10,1': 180,
#   'Samsung GT-I9192': 74,
#   'Samsung SM-G930U': 7,
#   '2014819': 4,
#   'XT1572': 8,
#   '4017F': 18,
#   'LG-P705': 1,
#   'Samsung SM-N9700': 1,
#   'Moto X Play': 119,
#   'XiaoMi Redmi Note 5A Prime': 21,
#   'Twist Metal': 15,
#   'moto e5 play': 285,
#   'POCOPHONE F1': 8,
#   'XT1058': 11,
#   'MS60X': 11,
#   'Asus FBBD': 41,
#   'E5563': 5,
#   'XT1078': 22,
#   'C103': 1,
#   'C5303': 3,
#   'Asus Z017DA': 5,
#   'iPhone9,3': 142,
#   'Samsung SM-J610FN': 9,
#   'S420': 3,
#   'Bluboo_S8_plus': 1,
#   'iPad3,4': 7,
#   'Samsung SM-J200G': 1,
#   'Samsung GT-I9200': 1,
#   'Samsung SM-A600GN': 1,
#   'Lenovo K520': 28,
#   'moto e5': 317,
#   'Moto G5S (XT1792)': 4,
#   'Samsung SM-A715F': 264,
#   'LG-H222': 18,
#   'iPad7,6': 4,
#   'Samsung GT-S5310B': 3,
#   'Asus Z00VD': 29,
#   '6039J': 3,
#   'STV-2000': 1,
#   'Lenovo L38111': 8,
#   'Samsung SM-J730GM': 57,
#   'Samsung SM-J105B': 286,
#   'MS60F': 26,
#   'itel A15': 2,
#   'MS50S': 5,
#   'Vivo XI+': 4,
#   'Asus Z012DA': 2,
#   'Moto G7 Plus': 2,
#   'HUAWEI LYO-L21': 1,
#   'LG-V500': 1,
#   'X23': 1,
#   'LGMP260': 5,
#   'HTC One M8': 3,
#   'Samsung GT-I8552B': 67,
#   'G3313': 2,
#   'Samsung SM-A205GN': 1,
#   'Samsung SM-A105FN': 18,
#   'LG-H820': 6,
#   'LG-M700': 270,
#   'Samsung SM-J200M': 115,
#   'BLU ENERGY DIAMOND': 1,
#   'MZ-Meizu M6s': 2,
#   'Tablet_DL_2810': 3,
#   'MYA-L23': 1,
#   'Samsung SM-G988U1': 3,
#   'LG-M150': 2,
#   'Samsung SM-G950U': 24,
#   'Quantum You 2': 8,
#   'Neffos C5': 1,
#   '71S': 2,
#   '6060S': 1,
#   'XiaoMi MI 8 Lite': 284,
#   'Samsung SM-G985F': 163,
#   'vivo 1805': 4,
#   'Asus Z00AD': 52,
#   'iPhone5,2': 7,
#   'MS40G': 57,
#   'Samsung GT-P3100': 7,
#   'Samsung SM-J710F': 6,
#   'LG-M400': 202,
#   'Samsung SM-G903F': 1,
#   'LG-H918': 1,
#   'Samsung SM-T715Y': 2,
#   'Asus X017DA': 210,
#   'XiaoMi Redmi Pro': 7,
#   'Samsung SM-G970U': 1,
#   'XT1706': 1,
#   'Samsung GT-S6293T': 11,
#   'iPad7,4': 6,
#   '4034E': 126,
#   'Samsung SM-J400M': 225,
#   'Lumia 435': 1,
#   'VF-1397': 1,
#   'XT1079': 2,
#   'ZUK Z2121': 6,
#   'Samsung SM-G920F': 5,
#   'Samsung SM-J727T1': 2,
#   'Samsung SM-A102U': 1,
#   '9008J': 42,
#   'Tablet_DL_2811': 18,
#   'Samsung SM-J700F': 7,
#   'Samsung SM-C5010': 5,
#   'XT1032': 37,
#   'Moto C Plus': 294,
#   'moto g7 plus': 1,
#   'LG-E470f': 2,
#   'LG-H830': 2,
#   'Samsung SM-J415G': 203,
#   'Samsung SM-A107F': 1,
#   'C2004': 2,
#   'Lenovo K33a48': 69,
#   'MUV': 18,
#   'Asus X013D': 120,
#   'Twist XL': 8,
#   'LG-D285': 2,
#   '4028E': 2,
#   'M7-4G': 1,
#   'LG-K428': 3,
#   'Samsung SM-G611M': 16,
#   'Samsung SM-G988B': 46,
#   'Lenovo TB-X304F': 5,
#   'Moto Z2 Play': 305,
#   'Samsung SM-J120AZ': 1,
#   'Samsung SM-T580': 3,
#   'XiaoMi Redmi 8A': 196,
#   'XT1064': 1,
#   'Grand M': 1,
#   'Samsung SM-A605G': 2,
#   '4009I': 1,
#   'C5 2019': 4,
#   'LG-K410': 21,
#   'Lenovo A1000': 9,
#   'D6603': 11,
#   'LG-E455': 2,
#   'TRT-L53': 1,
#   'Samsung SM-C7000': 12,
#   'Asus X00HD': 107,
#   'F3313': 9,
#   'Samsung SM-A920X': 2,
#   'Life One X2 Mini': 2,
#   'Asus X018DC': 1,
#   'XiaoMi Redmi 4': 8,
#   'LG-H522': 40,
#   'Samsung GT-I9515': 3,
#   'Samsung SM-G7102': 1,
#   'N5L': 3,
#   'Samsung SM-J3110': 9,
#   'E5343': 2,
#   'Samsung SM-N770F': 62,
#   'Plus E': 1,
#   'D6543': 22,
#   'Asus X01AD': 1,
#   'Samsung SM-A217M': 1,
#   'G011A': 6,
#   'NX563J': 4,
#   'Samsung SM-G925I': 215,
#   'iPad4,2': 9,
#   'G3226': 31,
#   'Samsung SM-J3119S': 1,
#   'LG-H870V': 2,
#   'Asus Z00A': 1,
#   'PRA-LX3': 4,
#   'LG-D295': 14,
#   'iPad5,3': 21,
#   '5049E': 10,
#   'D2306': 6,
#   'XT1662': 2,
#   'iPhone5,3': 10,
#   'Asus Z011D': 23,
#   'Z2 Plus': 2,
#   'XiaoMi MI 6X': 4,
#   'Lenovo TB3-X70F': 2,
#   'DIG-L03': 2,
#   'G3426': 15,
#   'Samsung SM-J810Y': 2,
#   'Samsung SM-A205G': 200,
#   'Samsung SM-G110B': 3,
#   'BLU DASH M2': 3,
#   'XT1097': 37,
#   'Samsung SM-J327W': 2,
#   'Samsung SM-G850M': 1,
#   'Samsung SM-T285': 4,
#   'Mi MIX 2': 4,
#   'Asus Z017D': 2,
#   'M7S_LITE': 2,
#   'Aquaris X Pro': 1,
#   'Advance 4.0M': 9,
#   'D2243': 1,
#   'Samsung SM-G925P': 3,
#   'Archos Access 50 Color 3G': 1,
#   'Asus X014D': 11,
#   'Samsung SM-G530A': 1,
#   'MS45S_A6_Teen': 1,
#   'Le X820': 3,
#   'Samsung SM-T515': 31,
#   'P10': 1,
#   'iPhone10,3': 160,
#   'Samsung SM-G360M': 35,
#   'Samsung GT-I9060I': 10,
#   'Moto E (4)': 318,
#   'ONEPLUS A3003': 1,
#   'G8341': 1,
#   'Quantum MUV UP': 8,
#   'Samsung SM-G925F': 12,
#   'NP-752Go': 23,
#   'Samsung GT-I9300': 9,
#   'GO3C': 12,
#   'iPhone9,4': 72,
#   'XiaoMi MI CC 9': 2,
#   'LG-H630': 32,
#   'Samsung SM-J810F': 6,
#   'Samsung SM-G3812B': 8,
#   'Samsung SM-C9000': 10,
#   'iPhone11,8': 77,
#   'LG-X220': 49,
#   'Lenovo L78051': 23,
#   'Samsung SM-T825': 13,
#   'Samsung SM-G532G': 11,
#   'E_Lite': 21,
#   'Pixel 2': 1,
#   'LG-D683': 1,
#   'iPhone12,1': 95,
#   'Samsung SM-J330FN': 1,
#   'Samsung SM-G975F': 242,
#   '62S': 5,
#   'Asus A007': 158,
#   'Moto G (5S)': 206,
#   'MS45S': 3,
#   'LG-H990': 11,
#   'BLU DASH L': 1,
#   'Other': 20601,
#   'Moto Z3 Play': 355,
#   'Lenovo A6020l36': 232,
#   'Samsung SM-A500M': 136,
#   'Asus Z01HDA': 11,
#   'M8 Pro': 1,
#   'MS50X': 75,
#   'Samsung SM-A102U1': 1,
#   'Samsung SM-A910F': 255,
#   'Samsung SM-J730G': 268,
#   'Samsung SM-J260T1': 1,
#   'CPH1909': 4,
#   'Samsung SM-J600GT': 190,
#   'Neffos X1 Lite': 2,
#   'XT1034': 2,
#   'Samsung SM-J500H': 27,
#   '5026J': 28,
#   'Asus X01BDA': 74,
#   'HUAWEI Y321-U051': 1,
#   'LG-H840': 53,
#   'Samsung SM-N9750': 1,
#   'Samsung SM-P550': 7,
#   'Asus ZB500KG': 6,
#   'Samsung SM-G925A': 11,
#   'BLU DASH X2': 2,
#   'XiaoMi MI PLAY': 94,
#   'iPad7,5': 25,
#   'Samsung SM-G903M': 87,
#   'iPad4,8': 1,
#   'Samsung SM-T331': 1,
#   'Samsung GT-I9070': 1,
#   'Samsung SM-A307G': 2,
#   'LG-D100': 15,
#   'Samsung SM-J737T1': 5,
#   'Samsung SM-J120M': 47,
#   'E6833': 1,
#   'Samsung SM-G950U1': 35,
#   'Samsung SM-T819': 3,
#   'Samsung SM-T595': 10,
#   'Samsung SM-J260F': 2,
#   'Samsung SM-G975U1': 7,
#   'Samsung SM-J250M': 268,
#   '5010E': 87,
#   'Positivo Next': 2,
#   'LG-M320': 255,
#   'Samsung GT-S5310C': 2,
#   'Samsung SM-J330F': 5,
#   'Samsung SM-J106F': 1,
#   'Asus X00RD': 174,
#   '5033J': 73,
#   'LG K350': 4,
#   'BLU Studio Touch': 4,
#   'Samsung SM-J500F': 7,
#   'Samsung GT-S7562L': 1,
#   'Samsung SM-N9600': 323,
#   'XT1069': 146,
#   'S31': 17,
#   'Lenovo K33b36': 236,
#   'YPY_S500': 2,
#   'Samsung SM-G531BT': 242,
#   'LG-M327': 1,
#   'HT16': 1,
#   'XiaoMi MI 5s Plus': 15,
#   'Samsung SM-A500H': 1,
#   'Samsung GT-I9515L': 57,
#   'XiaoMi Redmi K20 Pro Premium Edition': 1,
#   'S70': 3,
#   'NX573J': 2,
#   'NX551J': 9,
#   'LG-M257': 1,
#   '705-G': 7,
#   'XT1068': 108,
#   'Samsung SM-J110M': 23,
#   'Samsung SM-A505G': 28,
#   'Samsung SM-G610M': 219,
#   'LIO+': 14,
#   'Vivo 8': 2,
#   'Samsung SM-C7010': 1,
#   'ML-JI11-M7_3G_PLUS': 2,
#   'XiaoMi MI 5s': 12,
#   'Lenovo K51c78': 2,
#   'M6T': 11,
#   'Twist Metal 32GB': 31,
#   'C2304': 6,
#   'iPhone6,1': 129,
#   'JOY': 1,
#   'Samsung SM-G3502L': 6,
#   'iPad6,8': 1,
#   'vivo 1716': 3,
#   'Samsung GT-I9195': 5,
#   'LGMS210': 4,
#   'Samsung SM-J110L': 4,
#   'LG-D390': 1,
#   'iPhone12,5': 119,
#   'XiaoMi Redmi 6 Pro': 13,
#   'DUB-LX1': 5,
#   'BLU STUDIO C HD': 1,
#   'MS50G': 107,
#   'Samsung SM-E500M': 17,
#   'Vivo XI': 11,
#   'Asus Z00UD': 49,
#   'Samsung SM-P615': 1,
#   'C1604': 1,
#   'M9 Pro': 2,
#   'WAS-LX1': 1,
#   'victor': 2,
#   'iPhone8,2': 136,
#   'LG-H735': 3,
#   'Samsung SM-N950U1': 2,
#   'GO3C Plus': 15,
#   'CPH1803': 1,
#   'MS45S_A6': 5,
#   '5085J': 28,
#   'G_Max': 29,
#   'LG-X170fTV': 22,
#   'Samsung SM-G7102T': 15,
#   'Smartphone DL Horizon H8': 3,
#   'Nokia 6': 62,
#   'HDT-9421G': 1,
#   'You': 17,
#   'Q06': 4,
#   'LG-K580': 77,
#   'RNE-L23': 6,
#   'XiaoMi MI 6': 59,
#   'Asus Z01FD': 2,
#   'SC-02H': 5,
#   'Lenovo YB1-X90F': 6,
#   'vivo 1901': 1,
#   'Moto G (5)': 213,
#   'M10A-Lite': 6,
#   'Moto G5 (XT1672)': 5,
#   'LG-M151': 4,
#   'iPad11,1': 2,
#   'XiaoMi Redmi Note 3': 8,
#   'Lenovo B8000-F': 7,
#   'Samsung SM-G611MT': 276,
#   'HTC Desire 550': 2,
#   'Quartzo UP': 11,
#   'DASH C MUSIC': 1,
#   'Twist 2': 59,
#   'BLU Grand X LTE': 1,
#   'XiaoMi Redmi Note 9S': 67,
#   'Samsung SM-F700F': 3,
#   'C5': 16,
#   'LG-K420': 3,
#   'iPad4,4': 8,
#   'Samsung GT-S7582': 2,
#   'iPhone4,1': 1,
#   'LM-Q710.FGN': 30,
#   'WAS-LX3': 8,
#   'Lenovo Z90-7': 2,
#   'Samsung SM-G6000': 1,
#   'Samsung SM-G355M': 31,
#   'Samsung SM-A7050': 4,
#   'XiaoMi Redmi K30': 3,
#   'Samsung SM-G930F': 320,
#   'GOME_U9': 8,
#   'iPhone10,2': 180,
#   'Samsung SM-N7502': 6,
#   'MS60F_PLUS': 9,
#   'Nokia 6.1 Plus': 16,
#   'Samsung SM-A300M': 49,
#   'Asus X00ADA': 25,
#   'HTC 10': 1,
#   'LG M320': 1,
#   'Tablet_DL_2820': 6,
#   'Lenovo A6020a40': 34,
#   'ZB500KG': 19,
#   'Lenovo L78011': 7,
#   'fnac 5': 3,
#   'Asus X00BD': 1,
#   'Samsung SM-A405FN': 10,
#   'Samsung SM-G928G': 53,
#   'Samsung SM-G965U1': 34,
#   'Lenovo L38041': 22,
#   'ENERGY XL': 1,
#   'NX612J': 2,
#   'LG-H818': 44,
#   'Lenovo K10e70': 1,
#   'Samsung SM-J320M': 300,
#   'Che2-L11': 1,
#   'Samsung SM-G920T': 2,
#   'Lenovo K50-t5': 1,
#   'vernee_M5': 4,
#   'iPhone5,4': 85,
#   'LND-AL30': 2,
#   'iPhone8,4': 133,
#   'Asus I001DB': 3,
#   'PTB7QSG_3G': 3,
#   'Samsung GT-S6792L': 1,
#   'Samsung GT-S7582L': 22,
#   'RNE-L22': 1,
#   'R2 LTE': 3,
#   'LG M250': 6,
#   'GO 2': 2,
#   'Samsung SM-T380': 3,
#   'Samsung SM-A310M': 63,
#   'Samsung SM-N960U1': 2,
#   'Samsung SM-T560': 3,
#   'Samsung SM-G935L': 2,
#   'Samsung SM-G955N': 4,
#   'Samsung SM-N975U': 15,
#   'Quantum Go': 16,
#   'Samsung SM-G900FD': 4,
#   'Samsung KDDI': 5,
#   'Lenovo L18021': 6,
#   'LG-H540': 37,
#   'XT1039': 3,
#   'Asus Z017DC': 163,
#   'LG-E425f': 2,
#   'Samsung SM-J320H': 7,
#   'Samsung SM-T725': 19,
#   'LG-M210': 2,
#   'XiaoMi Redmi Note 7 Pro': 33,
#   'Asus Z01KDA': 18,
#   'iPad8,7': 1,
#   'C6503': 2,
#   'LG-H340': 1,
#   'Nokia 7': 4,
#   'LG-D125': 11,
#   'Samsung SM-J700H': 25,
#   'MS40S': 16,
#   'Samsung SM-J415F': 1,
#   'MS60Z': 16,
#   'LG-D724': 4,
#   'Vivo 5R': 5,
#   'VIE-L09': 1,
#   'M9-3G': 9,
#   'Samsung SM-T280': 36,
#   'Asus Z01RD': 170,
#   'Samsung SM-G531M': 57,
#   'Samsung SM-G891A': 3,
#   'Samsung SM-N920G': 48,
#   'G6 Plus': 2,
#   'Samsung SM-N970F': 252,
#   'XT1635-02': 298,
#   'Lenovo A1010a20': 10,
#   'VKY-L29': 1,
#   'Lenovo L58041': 6,
#   'BLU STUDIO G2': 4,
#   'XT1021': 2,
#   'Lenovo L78032': 19,
#   'XiaoMi Redmi 3': 8,
#   'Samsung SM-J200H': 4,
#   'Samsung SM-G318ML': 4,
#   'BLU ADVANCE 4.0 L2': 6,
#   'GO5E': 22,
#   'Samsung SM-G960W': 19,
#   'A3_Pro': 3,
#   'D5322': 6,
#   'LM-X410.F': 231,
#   'Studio View XL': 1,
#   'S10_Pro': 1,
#   'Samsung SM-G975U': 14,
#   'Le X526': 1,
#   'Samsung SM-A705MN': 258,
#   'iPod7,1': 2,
#   'LG-D805': 2,
#   'Lenovo P2a42': 1,
#   'F8331': 2,
#   'K10': 2,
#   'iPad8,1': 3,
#   'H3223': 12,
#   'dolphin': 3,
#   'Samsung SM-G920A': 2,
#   'Samsung SM-G570F': 12,
#   'Samsung SM-A260G': 7,
#   'Samsung GT-S6810B': 1,
#   'PRA-LX1': 3,
#   'Samsung SM-G955F': 307,
#   'Asus X008DC': 1,
#   'Asus X00DDB': 3,
#   'XT1663': 2,
#   'Samsung GT-I8552': 4,
#   'LG-H422': 49,
#   'Asus I01WD': 79,
#   'LG-E615f': 1,
#   'Samsung SM-G955U1': 25,
#   'LG-K500': 78,
#   'LG-X240': 61,
#   'Tablet_DL_4010': 1,
#   'TP601B': 1,
#   'Generic Smartphone': 186430,
#   'Samsung SM-G960U1': 23,
#   'iPad4,7': 4,
#   'Samsung SM-G973F': 299,
#   'Lenovo TB-X705F': 2,
#   'iPad7,11': 8,
#   'Samsung SM-G960F': 24,
#   'Samsung SM-T285M': 126,
#   'Advance 4.0 L3': 4,
#   'Twist Mini': 102,
#   'LG-E475f': 1,
#   'HT37Pro': 1,
#   'Samsung SM-J737U': 2,
#   'D2114': 4,
#   'C6843': 3,
#   'LG-AS330': 1,
#   'Samsung SM-J600F': 2,
#   'Samsung SM-A310F': 1,
#   'Samsung SM-A505GT': 169,
#   'Samsung SM-A315G': 39,
#   'Asus T00J': 2,
#   'D6633': 9,
#   'Asus X00DD': 6,
#   'SGP551': 4,
#   'Samsung GT-I9300I': 37,
#   'Samsung SM-N950F': 260,
#   'Samsung GT-S7275B': 2,
#   'GOME 2017M27A': 24,
#   'K10000 Pro': 3,
#   'Pixel C': 2,
#   'Samsung SM-A605FN': 4,
#   'Samsung SM-T111M': 3,
#   'Asus X00TD': 13,
#   'Moto G4 Plus': 3,
#   'Samsung SM-J610F': 1,
#   'XT1635-03': 4,
#   'XiaoMi MI 9 Transparent Edition': 5,
#   'Samsung SM-G900A': 2,
#   'LG-H910': 2,
#   'Samsung SM-P355M': 9,
#   '4055J': 7,
#   'Positivo US2070': 2,
#   'E2306': 1,
#   'Samsung SM-G975W': 3,
#   'LG-H870': 133,
#   'exbom': 1,
#   'Samsung GT-I9105P': 1,
#   'Samsung SM-J410F': 3,
#   '5046J': 11,
#   'Samsung SM-J200BT': 240,
#   'FRD-AL10': 3,
#   'XiaoMi Redmi Note 8T': 276,
#   'F8332': 1,
#   'Lenovo L38012': 4,
#   'E6603': 8,
#   'Samsung SM-G800H': 60,
#   'iPhone9,1': 150,
#   'MZ-M5c': 5,
#   'Mi A1': 2,
#   'G3116': 14,
#   'Samsung SM-G965F': 62,
#   'Samsung SM-N975U1': 5,
#   'Samsung SM-G928F': 6,
#   'LG-D690n': 61,
#   'Samsung SM-J410G': 187,
#   'G': 15,
#   'Samsung SM-G935A': 2,
#   'Le X522': 2,
#   'iPad11,3': 7,
#   'Life One X2': 2,
#   'Samsung SM-T510': 18,
#   'HP 7.1': 1,
#   'Samsung SM-T385M': 35,
#   'Samsung SM-G900P': 9,
#   'Samsung SM-A9000': 1,
#   'BLL-L22': 1,
#   'Samsung SM-G9650': 223,
#   'BV9500': 1,
#   'Samsung SM-N910C': 36,
#   'Samsung SM-G610F': 118,
#   'Samsung SM-A605GN': 299,
#   'LG-V400': 3,
#   'LG-K430': 235,
#   'XiaoMi Redmi 4A': 16,
#   'Lenovo K53a48': 7,
#   'iPhone7,1': 173,
#   'Samsung SM-A307GN': 2,
#   'Samsung SAMSUNG SM-N9005': 1,
#   'Samsung SM-J106B': 7,
#   'Samsung GT-I9063T': 46,
#   'XiaoMi MI MAX 3': 86,
#   'Samsung GT-S6313T': 2,
#   'R1 PLUS': 1,
#   'Samsung SM-G892A': 5,
#   'Asus X00DDA': 162,
#   'G3312': 2,
#   'Lenovo K8 Plus': 104,
#   'Samsung GT-N7000': 1,
#   'Moto G': 1,
#   'Z831': 1,
#   'Samsung SM-T700': 4,
#   'LG-K200': 209,
#   'BBD100-2': 4,
#   '5199I': 7,
#   'XT1650': 49,
#   'ATU-LX3': 2,
#   'Motorola MZ608': 5,
#   'XiaoMi Redmi 4X': 53,
#   'Samsung SM-M305M': 320,
#   'XT1040': 14,
#   'XiaoMi Redmi Note 4X': 9,
#   'Samsung SAMSUNG-SM-J320A': 1,
#   'Asus Z00LD': 22,
#   'D2403': 5,
#   'G4': 1,
#   'Samsung GT-N7105T': 2,
#   'LG-H873': 9,
#   'Samsung SM-N920S': 3,
#   'BLA-L29': 3,
#   'XiaoMi MI 8 Pro': 60,
#   'Samsung GT-I9295': 5,
#   'Samsung SM-T835': 1,
#   'iPad5,2': 3,
#   'E6633': 18,
#   'Asus X00ID': 159,
#   'C NOTE 2': 1,
#   'Samsung SM-T805M': 4,
#   'Samsung SM-J500FN': 1,
#   'ELUGA_A3_Pro': 1,
#   'Lenovo TB-8703F': 2,
#   'Samsung SM-J720M': 67,
#   'Kindle': 19,
#   'Lenovo A6020a46': 6,
#   'E6683': 1,
#   'Samsung SM-G970U1': 8,
#   'MZ-meizu C9': 1,
#   'Samsung SM-P605M': 2,
#   'Samsung GT-N5100': 4,
#   'Asus X017D': 138,
#   'XT1092': 1,
#   'vivo NEX A': 1,
#   'XiaoMi MI MAX 2': 32,
#   'Microsoft Virtual': 6,
#   'Nokia 3': 1,
#   'ML-SO-M7_3G_PLUS': 3,
#   'Lenovo P1c58': 1,
#   'C8': 1,
#   'XiaoMi MI 9 SE': 42,
#   '9008N': 62,
#   'S9+': 9,
#   'LG-D855': 8,
#   'NX569J': 3,
#   'LG-D175f': 11,
#   'TX92': 1,
#   'XiaoMi MI CC9 Pro': 7,
#   'Generic Feature Phone': 1,
#   '7048A': 3,
#   'Samsung SM-G930A': 3,
#   'moto g(6) play': 262,
#   'Samsung SM-A6060': 2,
#   'NP-852': 2,
#   'G8232': 1,
#   'iPad4,1': 19,
#   'Z2': 2,
#   'PlayStation 4': 23,
#   'LG-E989': 4,
#   'XT1580': 11,
#   'MHA-L29': 5,
#   'Twist (2018)': 78,
#   'moto e5 plus': 240,
#   'Lumia 640': 4,
#   'Inettv': 7,
#   'Samsung SM-G955W': 1,
#   'Samsung SM-J120H': 274,
#   'RNE-L21': 9,
#   'LM-G710': 12,
#   ...},
#  'os_family': {'Android': 251160,
#   'Chrome OS': 116,
#   'Fedora': 47,
#   'FreeBSD': 2,
#   'Linux': 269,
#   'Mac OS X': 339,
#   'Other': 59767,
#   'Ubuntu': 169,
#   'Windows 10': 13230,
#   'Windows 7': 2071,
#   'Windows 8': 166,
#   'Windows 8.1': 311,
#   'Windows Mobile': 1,
#   'Windows Phone': 59,
#   'Windows Vista': 70,
#   'Windows XP': 174,
#   'iOS': 7972}}

# %%
#parte 3
df = df.withColumn('30min_delta', F.coalesce( ( F.col('device_sent_timestamp') - F.lag(F.col('device_sent_timestamp')).over(window) ) / 60000 > 30, F.lit(True)) )

# %%
#window_delta = Window.partitionBy().orderBy(F.col('session_id'), F.col('device_sent_timestamp'))
df = df.withColumn('group_id', F.sum(F.col('30min_delta').cast('int')).over(window)   )

# %%
#df.show(20)

# %%
df_3 = df.groupby(F.col('browser_family'), F.col('device_family'),F.col('os_family'), F.col('group_id') ).agg(F.min(F.col('device_date')).alias('min_date'), F.max(F.col('device_date')).alias('max_date'))

# %%
#df_3.show(20)

# %%
df_3 = df_3.withColumn('diff_seconds', F.unix_timestamp(F.col('max_date')) - F.unix_timestamp(F.col('min_date')) )

# %%
#df_3.show(20)

# %%
#resultado parte 3
def median_by_column(column):
  return df_3.groupby(column).agg(F.expr('percentile_approx(diff_seconds, 0.5)').alias("mediana")).rdd.collectAsMap()

# %%
#2 fors estavam dando java memory heap  limite do google colab 12gb
columns = ['browser_family', 'os_family', 'device_family']
resultado_3_dict = {}
for column in columns:
  #df_4 = median_by_column(F.col(column))
  #in_dict = {}
  #for row in df_4.collect():
  #  in_dict[row[column]] = row['mediana']
  resultado_3_dict[column] = median_by_column(column)

# %%
resultado_3_dict
